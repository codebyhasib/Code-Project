# %% [markdown]
# <a href="https://colab.research.google.com/github/codebyhasib/Code-Project/blob/main/Advanced_Python_Problem%20Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prompt_tokens = 1500
completion_tokens = 600

print("Prompt Tokens:", prompt_tokens)
print("Completion Tokens:", completion_tokens)
# Out:
# Prompt Tokens: 1500
# Completion Tokens: 600

# %%
prompt_cost = (prompt_tokens / 1000) * 0.002

print("Prompt Cost:", prompt_cost)
# Out:
# Prompt Cost: 0.003

# %%
completion_cost = (completion_tokens / 1000) * 0.006

print("Completion Cost:", completion_cost)
# Out:
# Completion Cost: 0.0036

# %%
total_cost = prompt_cost + completion_cost

print("Total API Cost:", total_cost)
# Out:
# Total API Cost: 0.0066

# %%
print(f"Prompt Cost: ${prompt_cost:.4f}")
print(f"Completion Cost: ${completion_cost:.4f}")
print(f"Total API Cost: ${total_cost:.4f}")
# Out:
# Prompt Cost: $0.0030
# Completion Cost: $0.0036
# Total API Cost: $0.0066

# %% [markdown]
# All Code in One Cell

# %%
prompt_tokens = 1500
completion_tokens = 600

prompt_cost = (prompt_tokens / 1000) * 0.002
completion_cost = (completion_tokens / 1000) * 0.006

total_cost = prompt_cost + completion_cost

print(f"Prompt Cost: ${prompt_cost:.4f}")
print(f"Completion Cost: ${completion_cost:.4f}")
print(f"Total API Cost: ${total_cost:.4f}")
# Out:
# Prompt Cost: $0.0030
# Completion Cost: $0.0036
# Total API Cost: $0.0066

# %%
total_training_hours = 86

print("Total Training Hours:", total_training_hours)
# Out:
# Total Training Hours: 86

# %%
days = total_training_hours // 24

print("Full Days:", days)
# Out:
# Full Days: 3

# %%
remaining_hours = total_training_hours % 24

print("Remaining Hours:", remaining_hours)
# Out:
# Remaining Hours: 14

# %%
print(f"Training Uptime: {days} day(s) and {remaining_hours} hour(s)")
# Out:
# Training Uptime: 3 day(s) and 14 hour(s)

# %% [markdown]
# All Code in One Cell

# %%
total_training_hours = 86

days = total_training_hours // 24
remaining_hours = total_training_hours % 24

print(f"Training Uptime: {days} day(s) and {remaining_hours} hour(s)")
# Out:
# Training Uptime: 3 day(s) and 14 hour(s)

# %%
device_id_str = "108"
temp_reading_str = "98.4"
calibration_offset = 1.6

print("Device ID:", device_id_str)
print("Temperature Reading:", temp_reading_str)
print("Calibration Offset:", calibration_offset)
# Out:
# Device ID: 108
# Temperature Reading: 98.4
# Calibration Offset: 1.6

# %%
device_id = int(device_id_str)

print("Device ID:", device_id)
print("Data Type:", type(device_id))
# Out:
# Device ID: 108
# Data Type: <class 'int'>

# %%
converted_temp = float(temp_reading_str)

print("Converted Temperature:", converted_temp)
print("Data Type:", type(converted_temp))
# Out:
# Converted Temperature: 98.4
# Data Type: <class 'float'>

# %%
calibrated_temp = converted_temp + calibration_offset

print("Calibrated Temperature:", calibrated_temp)
# Out:
# Calibrated Temperature: 100.0

# %%
print("Data Type:", type(calibrated_temp))
# Out:
# Data Type: <class 'float'>

# %%
print(f"Device ID: {device_id} | Calibrated Temp: {calibrated_temp} | Data Type: {type(calibrated_temp)}")
# Out:
# Device ID: 108 | Calibrated Temp: 100.0 | Data Type: <class 'float'>

# %% [markdown]
# All Code in One Cell

# %%
device_id_str = "108"
temp_reading_str = "98.4"
calibration_offset = 1.6

device_id = int(device_id_str)
converted_temp = float(temp_reading_str)

calibrated_temp = converted_temp + calibration_offset

print(f"Device ID: {device_id} | Calibrated Temp: {calibrated_temp} | Data Type: {type(calibrated_temp)}")
# Out:
# Device ID: 108 | Calibrated Temp: 100.0 | Data Type: <class 'float'>

# %%
raw_filename = "   DATASET_sample_golden_retriever.JPEG   "

print(raw_filename)
# Out:
#    DATASET_sample_golden_retriever.JPEG

# %%
cleaned_filename = raw_filename.strip()

print(cleaned_filename)
# Out:
# DATASET_sample_golden_retriever.JPEG

# %%
cleaned_filename = cleaned_filename.lower()

print(cleaned_filename)
# Out:
# dataset_sample_golden_retriever.jpeg

# %%
cleaned_filename = cleaned_filename.replace(".jpeg", ".png")

print(cleaned_filename)
# Out:
# dataset_sample_golden_retriever.png

# %%
print(f"Cleaned Filename: {cleaned_filename}")
# Out:
# Cleaned Filename: dataset_sample_golden_retriever.png

# %% [markdown]
# All Code in One Cell

# %%
raw_filename = "   DATASET_sample_golden_retriever.JPEG   "

cleaned_filename = raw_filename.strip()
cleaned_filename = cleaned_filename.lower()
cleaned_filename = cleaned_filename.replace(".jpeg", ".png")

print(f"Cleaned Filename: {cleaned_filename}")
# Out:
# Cleaned Filename: dataset_sample_golden_retriever.png

# %%
handle = "@alex_ai_expert"

print(handle)
# Out:
# @alex_ai_expert

# %%
username = handle[1:]

print("Handle without @:", username)
# Out:
# Handle without @: alex_ai_expert

# %%
name = handle[1:5]

print("Extracted name:", name)
# Out:
# Extracted name: alex

# %%
starts_with_at = handle.startswith("@")

print("Starts with @:", starts_with_at)
# Out:
# Starts with @: True

# %% [markdown]
# All  Code in One Cell

# %%
handle = "@alex_ai_expert"

username = handle[1:]
name = handle[1:5]
starts_with_at = handle.startswith("@")

print("Handle without @:", username)
print("Extracted name:", name)
print("Starts with @:", starts_with_at)

# %%
encrypted_token = "tnedutS_IB_LM"

print("Encrypted Token:", encrypted_token)
# Out:
# Encrypted Token: tnedutS_IB_LM

# %%
decrypted_token = encrypted_token[::-1]

print(decrypted_token)
# Out:
# ML_BI_Student

# %%
print(f"Decrypted Token: {decrypted_token}")
# Out:
# Decrypted Token: ML_BI_Student

# %% [markdown]
# All Code in One Cell

# %%
encrypted_token = "tnedutS_IB_LM"

decrypted_token = encrypted_token[::-1]

print(f"Decrypted Token: {decrypted_token}")
# Out:
# Decrypted Token: ML_BI_Student

# %%
gpu_temp = 83

print("GPU Temperature:", gpu_temp, "°C")
# Out:
# GPU Temperature: 83 °C

# %%
status = "Normal: GPU operating within safe limits."
if gpu_temp >= 90:
    status = "CRITICAL: Thermal throttling activated!"

print(status)
# Out:
# Normal: GPU operating within safe limits.

# %%
if gpu_temp >= 90:
    status = "CRITICAL: Thermal throttling activated!"
elif gpu_temp >= 80:
    status = "WARNING: High temperature, fans set to 100%!"

print(status)
# Out:
# WARNING: High temperature, fans set to 100%!

# %%
if gpu_temp >= 90:
    status = "CRITICAL: Thermal throttling activated!"
elif gpu_temp >= 80:
    status = "WARNING: High temperature, fans set to 100%!"
elif gpu_temp >= 50:
    status = "NORMAL: GPU running smoothly."

print(status)
# Out:
# WARNING: High temperature, fans set to 100%!

# %%
if gpu_temp >= 90:
    status = "CRITICAL: Thermal throttling activated!"
elif gpu_temp >= 80:
    status = "WARNING: High temperature, fans set to 100%!"
elif gpu_temp >= 50:
    status = "NORMAL: GPU running smoothly."
else:
    status = "IDLE: GPU is cool."

print(status)
# Out:
# WARNING: High temperature, fans set to 100%!

# %% [markdown]
# All Code in One Cell

# %%
gpu_temp = 83

if gpu_temp >= 90:
    status = "CRITICAL: Thermal throttling activated!"
elif gpu_temp >= 80:
    status = "WARNING: High temperature, fans set to 100%!"
elif gpu_temp >= 50:
    status = "NORMAL: GPU running smoothly."
else:
    status = "IDLE: GPU is cool."

print(f"GPU Temp: {gpu_temp}°C -> {status}")
# Out:
# GPU Temp: 83°C -> WARNING: High temperature, fans set to 100%!

# %%
accuracy_score = 0.93

print("Accuracy Score:", accuracy_score)
# Out:
# Accuracy Score: 0.93

# %%
tier = "Development/Testing"
if accuracy_score >= 0.95:
    tier = "Production Ready (S-Tier)"

print(tier)
# Out:
# Development/Testing

# %%
if accuracy_score >= 0.95:
    tier = "Production Ready (S-Tier)"
elif accuracy_score >= 0.90:
    tier = "Acceptable Candidate (A-Tier)"

print(tier)
# Out:
# Acceptable Candidate (A-Tier)

# %%
if accuracy_score >= 0.95:
    tier = "Production Ready (S-Tier)"
elif accuracy_score >= 0.90:
    tier = "Acceptable Candidate (A-Tier)"
elif accuracy_score >= 0.80:
    tier = "Needs Tuning (B-Tier)"

print(tier)
# Out:
# Acceptable Candidate (A-Tier)

# %%
if accuracy_score >= 0.95:
    tier = "Production Ready (S-Tier)"
elif accuracy_score >= 0.90:
    tier = "Acceptable Candidate (A-Tier)"
elif accuracy_score >= 0.80:
    tier = "Needs Tuning (B-Tier)"
else:
    tier = "Retrain Required (F-Tier)"

print(tier)
# Out:
# Acceptable Candidate (A-Tier)

# %%
accuracy_percentage = accuracy_score * 100

print(accuracy_percentage)
# Out:
# 93.0

# %% [markdown]
# All Code in One Cell

# %%
accuracy_score = 0.93

if accuracy_score >= 0.95:
    tier = "Production Ready (S-Tier)"
elif accuracy_score >= 0.90:
    tier = "Acceptable Candidate (A-Tier)"
elif accuracy_score >= 0.80:
    tier = "Needs Tuning (B-Tier)"
else:
    tier = "Retrain Required (F-Tier)"

print(f"Accuracy: {accuracy_score * 100:.1f}% -> Tier: {tier}")
# Out:
# Accuracy: 93.0% -> Tier: Acceptable Candidate (A-Tier)

# %%
initial_loss = 0.75

print("Initial Loss:", initial_loss)
# Out:
# Initial Loss: 0.75

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 6):
    current_loss = round(0.75 - (i * 0.10), 2)
    print(current_loss)
# Out:
# 0.65
# 0.55
# 0.45
# 0.35
# 0.25

# %%
for i in range(1, 6):
    current_loss = round(0.75 - (i * 0.10), 2)
    print(f"Epoch {i}/5 | Loss: {current_loss}")
# Out:
# Epoch 1/5 | Loss: 0.65
# Epoch 2/5 | Loss: 0.55
# Epoch 3/5 | Loss: 0.45
# Epoch 4/5 | Loss: 0.35
# Epoch 5/5 | Loss: 0.25

# %% [markdown]
# All Code in One Cell

# %%
initial_loss = 0.75

for i in range(1, 6):
    current_loss = round(0.75 - (i * 0.10), 2)
    print(f"Epoch {i}/5 | Loss: {current_loss}")
# Out:
# Epoch 1/5 | Loss: 0.65
# Epoch 2/5 | Loss: 0.55
# Epoch 3/5 | Loss: 0.45
# Epoch 4/5 | Loss: 0.35
# Epoch 5/5 | Loss: 0.25

# %%
battery_level = 100

print("Battery Level:", battery_level)
# Out:
# Battery Level: 100

# %%
battery_level = 100

while battery_level > 20:
    print(f"Drone Flying... Battery at {battery_level}%")
    battery_level -= 20
# Out:
# Drone Flying... Battery at 100%
# Drone Flying... Battery at 80%
# Drone Flying... Battery at 60%
# Drone Flying... Battery at 40%

# %% [markdown]
# All Code in One Cell

# %%
battery_level = 100

while battery_level > 20:
    print(f"Drone Flying... Battery at {battery_level}%")
    battery_level -= 20

print("Low Battery Alert: Returning to charging dock!")
# Out:
# Drone Flying... Battery at 100%
# Drone Flying... Battery at 80%
# Drone Flying... Battery at 60%
# Drone Flying... Battery at 40%
# Low Battery Alert: Returning to charging dock!

# %%
val_losses = [0.88, 0.82, 0.79, 0.65, 0.38, 0.32, 0.28]

print(val_losses)
# Out:
# [0.88, 0.82, 0.79, 0.65, 0.38, 0.32, 0.28]

# %%
for loss in val_losses:
    print(loss)
# Out:
# 0.88
# 0.82
# 0.79
# 0.65
# 0.38
# 0.32
# 0.28

# %%
for loss in val_losses:
    if loss > 0.80:
        continue

    print(f"Checkpoint validation loss: {loss}")
# Out:
# Checkpoint validation loss: 0.79
# Checkpoint validation loss: 0.65
# Checkpoint validation loss: 0.38
# Checkpoint validation loss: 0.32
# Checkpoint validation loss: 0.28

# %%
for loss in val_losses:
    if loss > 0.80:
        continue

    if loss < 0.40:
        print(f"Early stopping triggered at loss {loss}! Model converged.")
        break

    print(f"Checkpoint validation loss: {loss}")
# Out:
# Checkpoint validation loss: 0.79
# Checkpoint validation loss: 0.65
# Early stopping triggered at loss 0.38! Model converged.

# %% [markdown]
# All Code in One Cell

# %%
val_losses = [0.88, 0.82, 0.79, 0.65, 0.38, 0.32, 0.28]

for loss in val_losses:
    if loss > 0.80:
        continue

    if loss < 0.40:
        print(f"Early stopping triggered at loss {loss}! Model converged.")
        break

    print(f"Checkpoint validation loss: {loss}")
# Out:
# Checkpoint validation loss: 0.79
# Checkpoint validation loss: 0.65
# Early stopping triggered at loss 0.38! Model converged.

# %%
def calculate_accuracy(correct_predictions, total_samples):
    print("Function created successfully!")

# %%
def calculate_accuracy(correct_predictions, total_samples):
    acc = (correct_predictions / total_samples) * 100
    print(acc)

# %%
calculate_accuracy(184, 200)
# Out:
# 92.0

# %%
def calculate_accuracy(correct_predictions, total_samples):
    acc = (correct_predictions / total_samples) * 100
    return acc

# %%
accuracy = calculate_accuracy(184, 200)

print(accuracy)
# Out:
# 92.0

# %%
def calculate_accuracy(correct_predictions, total_samples):
    acc = (correct_predictions / total_samples) * 100
    return f"Accuracy: {acc:.1f}% ({correct_predictions}/{total_samples})"

# %%
result = calculate_accuracy(184, 200)

print(result)
# Out:
# Accuracy: 92.0% (184/200)

# %% [markdown]
# All Code in One Cell

# %%
def calculate_accuracy(correct_predictions, total_samples):
    acc = (correct_predictions / total_samples) * 100
    return f"Accuracy: {acc:.1f}% ({correct_predictions}/{total_samples})"


result = calculate_accuracy(184, 200)

print(result)
# Out:
# Accuracy: 92.0% (184/200)

# %%
def build_hyperparameters(learning_rate=0.001, batch_size=32, optimizer="Adam"):
    return f"Config -> LR: {learning_rate}, Batch: {batch_size}, Optimizer: {optimizer}"

# %%
default_config = build_hyperparameters()

print(default_config)
# Out:
# Config -> LR: 0.001, Batch: 32, Optimizer: Adam

# %%
custom_config = build_hyperparameters(
    learning_rate=0.01,
    batch_size=64,
    optimizer="SGD"
)

print(custom_config)
# Out:
# Config -> LR: 0.01, Batch: 64, Optimizer: SGD

# %%
print(f"Default: {default_config}")
print(f"Custom: {custom_config}")
# Out:
# Default: Config -> LR: 0.001, Batch: 32, Optimizer: Adam
# Custom: Config -> LR: 0.01, Batch: 64, Optimizer: SGD

# %% [markdown]
# All Code in One Cell

# %%
def build_hyperparameters(learning_rate=0.001, batch_size=32, optimizer="Adam"):
    return f"Config -> LR: {learning_rate}, Batch: {batch_size}, Optimizer: {optimizer}"


default_config = build_hyperparameters()

custom_config = build_hyperparameters(
    learning_rate=0.01,
    batch_size=64,
    optimizer="SGD"
)

print(f"Default: {default_config}")
print(f"Custom: {custom_config}")
# Out:
# Default: Config -> LR: 0.001, Batch: 32, Optimizer: Adam
# Custom: Config -> LR: 0.01, Batch: 64, Optimizer: SGD

# %%
vocab = ["<PAD>", "<UNK>", "robot", "data"]

print(vocab)
# Out:
# ['<PAD>', '<UNK>', 'robot', 'data']

# %%
vocab.append("intelligence")

print(vocab)
# Out:
# ['<PAD>', '<UNK>', 'robot', 'data', 'intelligence']

# %%
vocab[1] = "<START>"

print(vocab)
# Out:
# ['<PAD>', '<START>', 'robot', 'data', 'intelligence']

# %%
vocab.remove("<PAD>")

print(vocab)
# Out:
# ['<START>', 'robot', 'data', 'intelligence']

# %%
vocab_size = len(vocab)

print("Vocab Size:", vocab_size)
# Out:
# Vocab Size: 4

# %%
print("Updated Vocab:", vocab)
print("Vocab Size:", len(vocab))
# Out:
# Updated Vocab: ['<START>', 'robot', 'data', 'intelligence']
# Vocab Size: 4

# %% [markdown]
# All Code in One Cell

# %%
vocab = ["<PAD>", "<UNK>", "robot", "data"]

vocab.append("intelligence")
vocab[1] = "<START>"
vocab.remove("<PAD>")

print("Updated Vocab:", vocab)
print("Vocab Size:", len(vocab))
# Out:
# Updated Vocab: ['<START>', 'robot', 'data', 'intelligence']
# Vocab Size: 4

# %%
pixel_tuple = (0.2, 0.8, 0.4)

print(pixel_tuple)
# Out:
# (0.2, 0.8, 0.4)

# %%
red_norm, green_norm, blue_norm = pixel_tuple

print("Red:", red_norm)
print("Green:", green_norm)
print("Blue:", blue_norm)
# Out:
# Red: 0.2
# Green: 0.8
# Blue: 0.4

# %%
red = int(red_norm * 255)

print("Red:", red)
# Out:
# Red: 51

# %%
green = int(green_norm * 255)

print("Green:", green)
# Out:
# Green: 204

# %%
blue = int(blue_norm * 255)

print("Blue:", blue)
# Out:
# Blue: 102

# %%
print(f"Scaled RGB: R={red}, G={green}, B={blue}")
# Out:
# Scaled RGB: R=51, G=204, B=102

# %% [markdown]
# All Code in One Cell

# %%
pixel_tuple = (0.2, 0.8, 0.4)

red_norm, green_norm, blue_norm = pixel_tuple

red = int(red_norm * 255)
green = int(green_norm * 255)
blue = int(blue_norm * 255)

print(f"Scaled RGB: R={red}, G={green}, B={blue}")
# Out:
# Scaled RGB: R=51, G=204, B=102

# %%
required_skills = {"Python", "SQL", "Machine Learning", "Git"}
candidate_skills = {"Python", "Git", "Java", "Docker"}

print("Required Skills:", required_skills)
print("Candidate Skills:", candidate_skills)
# Out:
# Required Skills: {'Git', 'SQL', 'Python', 'Machine Learning'}
# Candidate Skills: {'Git', 'Python', 'Java', 'Docker'}

# %%
matching_skills = required_skills & candidate_skills

print(matching_skills)
# Out:
# {'Git', 'Python'}

# %%
all_combined_skills = required_skills | candidate_skills

print(all_combined_skills)
# Out:
# {'SQL', 'Python', 'Machine Learning', 'Java', 'Git', 'Docker'}

# %%
missing_skills = required_skills - candidate_skills

print(missing_skills)
# Out:
# {'SQL', 'Machine Learning'}

# %%
print("Matching Skills:", sorted(matching_skills))
print("All Combined Skills:", sorted(all_combined_skills))
print("Missing Required Skills:", sorted(missing_skills))
# Out:
# Matching Skills: ['Git', 'Python']
# All Combined Skills: ['Docker', 'Git', 'Java', 'Machine Learning', 'Python', 'SQL']
# Missing Required Skills: ['Machine Learning', 'SQL']

# %% [markdown]
# All Code in One Cell

# %%
required_skills = {"Python", "SQL", "Machine Learning", "Git"}
candidate_skills = {"Python", "Git", "Java", "Docker"}

matching_skills = required_skills & candidate_skills
all_combined_skills = required_skills | candidate_skills
missing_skills = required_skills - candidate_skills

print("Matching Skills:", sorted(matching_skills))
print("All Combined Skills:", sorted(all_combined_skills))
print("Missing Required Skills:", sorted(missing_skills))
# Out:
# Matching Skills: ['Git', 'Python']
# All Combined Skills: ['Docker', 'Git', 'Java', 'Machine Learning', 'Python', 'SQL']
# Missing Required Skills: ['Machine Learning', 'SQL']

# %%
agent_profile = {
    "name": "Aura",
    "model": "Gemini-2.0",
    "temperature": 0.7
}

print(agent_profile)
# Out:
# {'name': 'Aura', 'model': 'Gemini-2.0', 'temperature': 0.7}

# %%
agent_name = agent_profile["name"]
base_model = agent_profile["model"]

print(f"Agent Name: {agent_name} | Base Model: {base_model}")
# Out:
# Agent Name: Aura | Base Model: Gemini-2.0

# %%
agent_profile["max_tokens"] = 2048

print(agent_profile)
# Out:
# {'name': 'Aura', 'model': 'Gemini-2.0', 'temperature': 0.7, 'max_tokens': 2048}

# %%
agent_profile["temperature"] = 0.2

print(agent_profile)
# Out:
# {'name': 'Aura', 'model': 'Gemini-2.0', 'temperature': 0.2, 'max_tokens': 2048}

# %%
print("--- Configuration Summary ---")

for key, value in agent_profile.items():
    print(f"{key} = {value}")
# Out:
# --- Configuration Summary ---
# name = Aura
# model = Gemini-2.0
# temperature = 0.2
# max_tokens = 2048

# %% [markdown]
# All Code in One Cell

# %%
agent_profile = {
    "name": "Aura",
    "model": "Gemini-2.0",
    "temperature": 0.7
}

# Access name and model
agent_name = agent_profile["name"]
base_model = agent_profile["model"]

print(f"Agent Name: {agent_name} | Base Model: {base_model}")

# Add max_tokens
agent_profile["max_tokens"] = 2048

# Update temperature
agent_profile["temperature"] = 0.2

# Iterate through all configuration settings
print("--- Configuration Summary ---")

for key, value in agent_profile.items():
    print(f"{key} = {value}")
# Out:
# Agent Name: Aura | Base Model: Gemini-2.0
# --- Configuration Summary ---
# name = Aura
# model = Gemini-2.0
# temperature = 0.2
# max_tokens = 2048

# %%
signals = [-5, 12, 0, -8, 25, 30, -3, 18]

print(signals)
# Out:
# [-5, 12, 0, -8, 25, 30, -3, 18]

# %%
positive_signals = [s for s in signals if s > 0]

print(positive_signals)
# Out:
# [12, 25, 30, 18]

# %%
amplified_signals = [s * 2 for s in positive_signals]

print(amplified_signals)
# Out:
# [24, 50, 60, 36]

# %%
print("Positive signals:", positive_signals)
print("Amplified signals:", amplified_signals)
# Out:
# Positive signals: [12, 25, 30, 18]
# Amplified signals: [24, 50, 60, 36]

# %% [markdown]
# All Code in One Cell

# %%
signals = [-5, 12, 0, -8, 25, 30, -3, 18]

# Keep only positive signals
positive_signals = [s for s in signals if s > 0]

# Double each positive signal
amplified_signals = [s * 2 for s in positive_signals]

# Print both lists
print("Positive signals:", positive_signals)
print("Amplified signals:", amplified_signals)
# Out:
# Positive signals: [12, 25, 30, 18]
# Amplified signals: [24, 50, 60, 36]

# %%
apply_discount = lambda price, discount_percent: price * (1 - discount_percent / 100)

# %%
discounted_price = apply_discount(200, 15)

# %%
print(f"Discounted Price: ${discounted_price:.2f}")
# Out:
# Discounted Price: $170.00

# %% [markdown]
# All Code in One Cell

# %%
apply_discount = lambda price, discount_percent: price * (1 - discount_percent / 100)

discounted_price = apply_discount(200, 15)

print(f"Discounted Price: ${discounted_price:.2f}")
# Out:
# Discounted Price: $170.00

# %%
raw_headers = ["  AGE  ", "  ANNUAL_INCOME  ", "  CREDIT_SCORE  ", "  LOAN_STATUS  "]

# %%
normalized_headers = list(map(lambda header: header.strip().lower(), raw_headers))

# %%
print("Normalized Headers:", normalized_headers)
# Out:
# Normalized Headers: ['age', 'annual_income', 'credit_score', 'loan_status']

# %% [markdown]
# All Code in One Cell

# %%
raw_headers = ["  AGE  ", "  ANNUAL_INCOME  ", "  CREDIT_SCORE  ", "  LOAN_STATUS  "]

normalized_headers = list(map(lambda header: header.strip().lower(), raw_headers))

print("Normalized Headers:", normalized_headers)
# Out:
# Normalized Headers: ['age', 'annual_income', 'credit_score', 'loan_status']

# %%
latencies_ms = [12, 18, 250, 15, 320, 22, 14, 19, 150]

# %%
normal_latencies = list(filter(lambda latency: latency < 100, latencies_ms))

# %%
print("Normal Latencies (< 100ms):", normal_latencies)
# Out:
# Normal Latencies (< 100ms): [12, 18, 15, 22, 14, 19]

# %% [markdown]
# All Code in One Cell

# %%
latencies_ms = [12, 18, 250, 15, 320, 22, 14, 19, 150]

normal_latencies = list(filter(lambda latency: latency < 100, latencies_ms))

print("Normal Latencies (< 100ms):", normal_latencies)

# %%
uploaded_files = [
    "data.csv",
    "image1.png",
    "weights.pt",
    "test.csv",
    "image2.PNG",
    "config.json",
    "data2.CSV"
]

# %%
unique_extensions = {
    file.split(".")[-1].lower()
    for file in uploaded_files
}

# %%
print("Unique File Extensions:", sorted(unique_extensions))
# Out:
# Unique File Extensions: ['csv', 'json', 'png', 'pt']

# %% [markdown]
# All Code in One Cell

# %%
uploaded_files = [
    "data.csv",
    "image1.png",
    "weights.pt",
    "test.csv",
    "image2.PNG",
    "config.json",
    "data2.CSV"
]

unique_extensions = {
    file.split(".")[-1].lower()
    for file in uploaded_files
}

print("Unique File Extensions:", sorted(unique_extensions))
# Out:
# Unique File Extensions: ['csv', 'json', 'png', 'pt']

# %%
with open("model_training.log", "w") as file:
    file.write("[INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%\n")
    file.write("[INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%\n")

# %%
with open("model_training.log", "r") as file:
    lines = file.readlines()

# %%
print("--- Reading model_training.log ---")

for line in lines:
    print(line, end="")
# Out:
# --- Reading model_training.log ---
# [INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%
# [INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%

# %% [markdown]
# All Code in One Cell

# %%
with open("model_training.log", "w") as file:
    file.write("[INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%\n")
    file.write("[INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%\n")

with open("model_training.log", "r") as file:
    lines = file.readlines()

print("--- Reading model_training.log ---")

for line in lines:
    print(line, end="")
# Out:
# --- Reading model_training.log ---
# [INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%
# [INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%

# %%
import csv

# %%
with open("benchmarks.csv", "w", newline="") as file:
    writer = csv.writer(file)

    writer.writerow(["Model", "Latency_ms", "Accuracy"])
    writer.writerow(["ResNet-50", "45", "92.4%"])
    writer.writerow(["MobileNet", "14", "88.1%"])
    writer.writerow(["VisionTransformer", "78", "95.6%"])

# %%
with open("benchmarks.csv", "r") as file:
    reader = csv.DictReader(file)

    print("--- Model Benchmarks ---")

    for row in reader:
        print(f"Model: {row['Model']} | Latency: {row['Latency_ms']} ms")
# Out:
# --- Model Benchmarks ---
# Model: ResNet-50 | Latency: 45 ms
# Model: MobileNet | Latency: 14 ms
# Model: VisionTransformer | Latency: 78 ms

# %% [markdown]
# All Code in One Cell

# %%
import csv

with open("benchmarks.csv", "w", newline="") as file:
    writer = csv.writer(file)

    writer.writerow(["Model", "Latency_ms", "Accuracy"])
    writer.writerow(["ResNet-50", "45", "92.4%"])
    writer.writerow(["MobileNet", "14", "88.1%"])
    writer.writerow(["VisionTransformer", "78", "95.6%"])

with open("benchmarks.csv", "r") as file:
    reader = csv.DictReader(file)

    print("--- Model Benchmarks ---")

    for row in reader:
        print(f"Model: {row['Model']} | Latency: {row['Latency_ms']} ms")
# Out:
# --- Model Benchmarks ---
# Model: ResNet-50 | Latency: 45 ms
# Model: MobileNet | Latency: 14 ms
# Model: VisionTransformer | Latency: 78 ms

# %%
import json

pipeline_config = {
    "pipeline_name": "SentimentAnalysis",
    "max_sequence_length": 128,
    "pretrained_weights": "bert-base-uncased",
    "fine_tuned": True
}

# %%
with open("pipeline_config.json", "w") as file:
    json.dump(pipeline_config, file, indent=4)

# %%
with open("pipeline_config.json", "r") as file:
    loaded_config = json.load(file)

# %%
print("Loaded Pipeline:", loaded_config["pipeline_name"])
print("Max Sequence Length:", loaded_config["max_sequence_length"])
# Out:
# Loaded Pipeline: SentimentAnalysis
# Max Sequence Length: 128

# %% [markdown]
# All Code in One Cell

# %%
import json

pipeline_config = {
    "pipeline_name": "SentimentAnalysis",
    "max_sequence_length": 128,
    "pretrained_weights": "bert-base-uncased",
    "fine_tuned": True
}

with open("pipeline_config.json", "w") as file:
    json.dump(pipeline_config, file, indent=4)

with open("pipeline_config.json", "r") as file:
    loaded_config = json.load(file)

print("Loaded Pipeline:", loaded_config["pipeline_name"])
print("Max Sequence Length:", loaded_config["max_sequence_length"])
# Out:
# Loaded Pipeline: SentimentAnalysis
# Max Sequence Length: 128

# %%
def safe_feature_ratio(numerator, denominator):
    try:
        return round(numerator / denominator, 2)
    except ZeroDivisionError:
        print("Warning: Denominator is 0. Returning 0.0")
        return 0.0

# %%
ratio1 = safe_feature_ratio(150, 3)
print("Ratio 1:", ratio1)
# Out:
# Ratio 1: 50.0

# %%
ratio2 = safe_feature_ratio(150, 0)
print("Ratio 2:", ratio2)
# Out:
# ...
# Ratio 2: 0.0

# %% [markdown]
# All Code in One Cell

# %%
def safe_feature_ratio(numerator, denominator):
    try:
        return round(numerator / denominator, 2)
    except ZeroDivisionError:
        print("Warning: Denominator is 0. Returning 0.0")
        return 0.0


ratio1 = safe_feature_ratio(150, 3)
print("Ratio 1:", ratio1)

ratio2 = safe_feature_ratio(150, 0)
print("Ratio 2:", ratio2)
# Out:
# Ratio 1: 50.0
# ...
# Ratio 2: 0.0

# %%
def parse_sensor_reading(raw_val):
    try:
        return float(raw_val)
    except ValueError:
        print(f"Error: Cannot parse reading '{raw_val}' as numeric.")
        return None

# %%
reading1 = parse_sensor_reading("74.5")
print("Parsed Reading:", reading1)
# Out:
# Parsed Reading: 74.5

# %%
reading2 = parse_sensor_reading("CORRUPTED_SIGNAL")
print("Parsed Reading:", reading2)
# Out:
# Error: Cannot parse reading 'CORRUPTED_SIGNAL' as numeric.
# Parsed Reading: None

# %% [markdown]
# All Code in One Cell

# %%
def parse_sensor_reading(raw_val):
    try:
        return float(raw_val)
    except ValueError:
        print(f"Error: Cannot parse reading '{raw_val}' as numeric.")
        return None


reading1 = parse_sensor_reading("74.5")
print("Parsed Reading:", reading1)

reading2 = parse_sensor_reading("CORRUPTED_SIGNAL")
print("Parsed Reading:", reading2)
# Out:
# Parsed Reading: 74.5
# Error: Cannot parse reading 'CORRUPTED_SIGNAL' as numeric.
# Parsed Reading: None

# %%
model_name = "RandomForestClassifier"
f1_score = 0.9428
inference_time_sec = 0.0345

# %%
print(
    f"[EVALUATION] Model: {model_name} | "
    f"F1-Score: {f1_score:.2%} | "
    f"Latency: {inference_time_sec:.3f}s"
)
# Out:
# [EVALUATION] Model: RandomForestClassifier | F1-Score: 94.28% | Latency: 0.035s

# %% [markdown]
# All Code in One Cell

# %%
model_name = "RandomForestClassifier"
f1_score = 0.9428
inference_time_sec = 0.0345

print(
    f"[EVALUATION] Model: {model_name} | "
    f"F1-Score: {f1_score:.2%} | "
    f"Latency: {inference_time_sec:.3f}s"
)
# Out:
# [EVALUATION] Model: RandomForestClassifier | F1-Score: 94.28% | Latency: 0.035s

# %%
import math

x1, y1 = 2, 3
x2, y2 = 6, 7

# %%
distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# %%
print(f"Euclidean Distance: {distance:.2f}")
# Out:
# Euclidean Distance: 5.66

# %% [markdown]
# All Code in One Cell

# %%
import math

x1, y1 = 2, 3
x2, y2 = 6, 7

distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

print(f"Euclidean Distance: {distance:.2f}")
# Out:
# Euclidean Distance: 5.66

# %%
import re

log_data = "User [ID:402] accessed file [data_v1.csv] with status [SUCCESS] at latency [45ms]."

# %%
tokens = re.findall(r"\[(.*?)\]", log_data)

# %%
print("Extracted Log Tokens:", tokens)
# Out:
# Extracted Log Tokens: ['ID:402', 'data_v1.csv', 'SUCCESS', '45ms']

# %% [markdown]
# All Code in One Cell

# %%
import re

log_data = "User [ID:402] accessed file [data_v1.csv] with status [SUCCESS] at latency [45ms]."

tokens = re.findall(r"\[(.*?)\]", log_data)

print("Extracted Log Tokens:", tokens)
# Out:
# Extracted Log Tokens: ['ID:402', 'data_v1.csv', 'SUCCESS', '45ms']
